# %%
import category_encoders as ce
import pandas as pd
train_df=pd.DataFrame({"Degree":["High School","Masters","Phd","Diploma","High School","Phd","Bachalors","Bachalors"]})
train_df
# Out:
#         Degree
# 0  High School
# 1      Masters
# 2          Phd
# 3      Diploma
# 4  High School
# 5          Phd
# 6    Bachalors
# 7    Bachalors

# %%
encoder=ce.OrdinalEncoder(cols=['Degree'],return train_df=True,mapping=[{"cols":"Degree","mapping":{"None":0,"High School":1,"Masters":2,"Phd":3,"Bachalors":4,
                                                                                              "Diploma":5}}])
# Out:
#   Cell In[8], line 1
#     encoder=ce.OrdinalEncoder(cols=['Degree'],return train_df=True,mapping=[{"cols":"Degree","mapping":{"None":0,"High School":1,"Masters":2,"Phd":3,"Bachalors":4,
#                                               ^
# SyntaxError: invalid syntax
