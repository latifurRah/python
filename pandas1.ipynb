# %%
import pandas as pd
data={
    "cars":["BMW","volvo","ford"],
    "passing":[3,7,2]
}
data_frame=pd.DataFrame(data)
print(data_frame)
# Out:
#     cars  passing
# 0    BMW        3
# 1  volvo        7
# 2   ford        2

# %%
s=pd.Series([1,2,3])
s.describe()
# Out:
# count    3.0
# mean     2.0
# std      1.0
# min      1.0
# 25%      1.5
# 50%      2.0
# 75%      2.5
# max      3.0
# dtype: float64

# %% [markdown]
# ### Data import from csv

# %%
pip.in
