# %%
import pandas as pd
df=pd.read_csv("keralas.csv")
df
print(df.duplicated())
print('\n')
df.shape
df.describe()
df.info
df.isnull()
column=df["JAN"]
column.describe()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# Length: 115, dtype: bool
# count    115.000000
# mean      12.246957
# std       15.538923
# min        0.000000
# 25%        2.250000
# 50%        6.000000
# 75%       17.750000
# max       83.500000
# Name: JAN, dtype: float64
